# %%
#Importing libraries

import sys, os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam, SGD, Nadam
from keras.regularizers import l2
from matplotlib import pyplot as plt

num_features = 64
num_labels = 7
batch_size = 64
epochs = 100
width, height = 48, 48

x = np.load('./fdataX.npy')
y = np.load('./flabels.npy')

x -= np.mean(x, axis=0)
x /= np.std(x, axis=0)

#splitting into training, validation and testing data
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=41)

#saving the test samples 
np.save('modXtest', X_test)
np.save('modytest', y_test)

# %%
#desinging the CNN
model = Sequential()

model.add(Conv2D(num_features, kernel_size=(3, 3), activation='relu', input_shape=(width, height, 1), data_format='channels_last', kernel_regularizer=l2(0.01)))
model.add(Conv2D(num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())

model.add(Dense(2*2*2*num_features, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2*2*num_features, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2*num_features, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(num_labels, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 46, 46, 64)        640
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 46, 46, 64)        36928
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 23, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 11, 11, 256)       295168
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 5, 5, 512)         1180160
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 5,905,863
# Trainable params: 5,902,151
# Non-trainable params: 3,712
# _________________________________________________________________

# %%
#Compliling the model with adam optimixer and categorical crossentropy loss
model.compile(loss=categorical_crossentropy,
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
              metrics=['accuracy'])

#training the model
model.fit(np.array(X_train), np.array(y_train),
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(np.array(X_valid), np.array(y_valid)),
          shuffle=True)

#saving the  model as json file
fer_json = model.to_json()
with open("fer.json", "w") as json_file:
    json_file.write(fer_json)
model.save_weights("fer.h5")
print("Saved model to disk")
# Out:
# Epoch 1/100
# 455/455 [==============================] - 652s 1s/step - loss: 1.9770 - accuracy: 0.2175 - val_loss: 1.8278 - val_accuracy: 0.2594
# Epoch 2/100
# 455/455 [==============================] - 669s 1s/step - loss: 1.7872 - accuracy: 0.2758 - val_loss: 1.6952 - val_accuracy: 0.3142
# Epoch 3/100
# 455/455 [==============================] - 677s 1s/step - loss: 1.6874 - accuracy: 0.3253 - val_loss: 1.5967 - val_accuracy: 0.3734
# Epoch 4/100
# 455/455 [==============================] - 649s 1s/step - loss: 1.5751 - accuracy: 0.3839 - val_loss: 1.4660 - val_accuracy: 0.4508
# Epoch 5/100
# 455/455 [==============================] - 663s 1s/step - loss: 1.4937 - accuracy: 0.4174 - val_loss: 1.4236 - val_accuracy: 0.4514
# Epoch 6/100
# 455/455 [==============================] - 1139s 3s/step - loss: 1.4351 - accuracy: 0.4468 - val_loss: 1.3204 - val_accuracy: 0.4938
# Epoch 7/100
# 455/455 [==============================] - 655s 1s/step - loss: 1.3909 - accuracy: 0.4692 - val_loss: 1.2986 - val_accuracy: 0.5121
# Epoch 8/100
# 455/455 [==============================] - 640s 1s/step - loss: 1.3532 - accuracy: 0.4791 - val_loss: 1.2452 - val_accuracy: 0.5310
# Epoch 9/100
# 455/455 [==============================] - 666s 1s/step - loss: 1.3122 - accuracy: 0.5046 - val_loss: 1.2276 - val_accuracy: 0.5272
# Epoch 10/100
# 455/455 [==============================] - 689s 2s/step - loss: 1.2946 - accuracy: 0.5140 - val_loss: 1.2031 - val_accuracy: 0.5412
# Epoch 11/100
# 455/455 [==============================] - 673s 1s/step - loss: 1.2593 - accuracy: 0.5302 - val_loss: 1.2127 - val_accuracy: 0.5480
# Epoch 12/100
# 455/455 [==============================] - 902s 2s/step - loss: 1.2431 - accuracy: 0.5368 - val_loss: 1.1477 - val_accuracy: 0.5712
# Epoch 13/100
# 455/455 [==============================] - 646s 1s/step - loss: 1.2184 - accuracy: 0.5492 - val_loss: 1.1403 - val_accuracy: 0.5678
# Epoch 14/100
# 455/455 [==============================] - 639s 1s/step - loss: 1.1978 - accuracy: 0.5558 - val_loss: 1.1310 - val_accuracy: 0.5827
# Epoch 15/100
# 455/455 [==============================] - 637s 1s/step - loss: 1.1757 - accuracy: 0.5679 - val_loss: 1.1061 - val_accuracy: 0.5960
# Epoch 16/100
# 455/455 [==============================] - 636s 1s/step - loss: 1.1426 - accuracy: 0.5781 - val_loss: 1.1005 - val_accuracy: 0.5820
# Epoch 17/100
# 455/455 [==============================] - 648s 1s/step - loss: 1.1303 - accuracy: 0.5852 - val_loss: 1.1003 - val_accuracy: 0.5950
# Epoch 18/100
# 455/455 [==============================] - 667s 1s/step - loss: 1.1030 - accuracy: 0.5976 - val_loss: 1.0796 - val_accuracy: 0.6084
# Epoch 19/100
# 455/455 [==============================] - 647s 1s/step - loss: 1.0868 - accuracy: 0.6062 - val_loss: 1.0727 - val_accuracy: 0.6090
# Epoch 20/100
# 455/455 [==============================] - 677s 1s/step - loss: 1.0673 - accuracy: 0.6143 - val_loss: 1.0796 - val_accuracy: 0.6090
# Epoch 21/100
# 455/455 [==============================] - 688s 2s/step - loss: 1.0357 - accuracy: 0.6234 - val_loss: 1.0432 - val_accuracy: 0.6217
# Epoch 22/100
# 455/455 [==============================] - 680s 1s/step - loss: 1.0184 - accuracy: 0.6324 - val_loss: 1.0562 - val_accuracy: 0.6142
# Epoch 23/100
# 455/455 [==============================] - 661s 1s/step - loss: 1.0033 - accuracy: 0.6377 - val_loss: 1.0314 - val_accuracy: 0.6300
# Epoch 24/100
# 455/455 [==============================] - 651s 1s/step - loss: 0.9850 - accuracy: 0.6415 - val_loss: 1.0339 - val_accuracy: 0.6328
# Epoch 25/100
# 455/455 [==============================] - 656s 1s/step - loss: 0.9698 - accuracy: 0.6515 - val_loss: 1.0458 - val_accuracy: 0.6211
# Epoch 26/100
# 455/455 [==============================] - 646s 1s/step - loss: 0.9459 - accuracy: 0.6577 - val_loss: 1.0451 - val_accuracy: 0.6124
# Epoch 27/100
# 455/455 [==============================] - 669s 1s/step - loss: 0.9360 - accuracy: 0.6642 - val_loss: 1.0450 - val_accuracy: 0.6211
# Epoch 28/100
# 455/455 [==============================] - 662s 1s/step - loss: 0.9130 - accuracy: 0.6724 - val_loss: 1.0353 - val_accuracy: 0.6297
# Epoch 29/100
# 455/455 [==============================] - 643s 1s/step - loss: 0.8962 - accuracy: 0.6783 - val_loss: 1.0488 - val_accuracy: 0.6300
# Epoch 30/100
# 152/455 [=========>....................] - ETA: 7:01 - loss: 0.8769 - accuracy: 0.6855
